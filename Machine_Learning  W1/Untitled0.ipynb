# %% [markdown]
# <a href="https://colab.research.google.com/github/ANAS-MUHAISEN/Machine-Learning-Week1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16525, done.
# remote: Total 16525 (delta 0), reused 0 (delta 0), pack-reused 16525
# Receiving objects: 100% (16525/16525), 15.00 MiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (11361/11361), done.
# /content/yolov5/yolov5/yolov5
# Setup complete. Using torch 2.2.1+cu121 (CPU)

# %%
# !pip install roboflow
import roboflow

# %%
api_key = "<Pwxh7PUB7bw7rz5ZgS0k>"

# %%
rf = roboflow.Roboflow(api_key=api_key, model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-2f6135367ffe> in <cell line: 2>()
#       1 from roboflow import Roboflow
# ----> 2 rf = Roboflow(model_format="yolov5", notebook="ultralytics")
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     228         self.notebook = notebook
#     229         self.onboarding = False
# --> 230         self.auth()
#     231
#     232     def auth(self):
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in auth(self)
#     231
#     232     def auth(self):
# --> 233         r = check_key(self.api_key, self.model_format, self.notebook)
#     234
#     235         if r == "onboarding":
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in check_key(api_key, model, notebook, num_retries)
# ...

# %%
from roboflow import Roboflow

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Pwxh7PUB7bw7rz5ZgS0k")
project = rf.workspace("traffic-ai-8xnmy").project("car-fire-yssjr")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/Car-fire-1 in yolov5pytorch:: 100%|██████████| 174/174 [00:00<00:00, 4810.84it/s]

# %%
# !python train.py --img 81 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-04-04 11:44:12.113681: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 11:44:12.113767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 11:44:12.311235: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/Car-fire-1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/datasets/Car-fire-1/test/images/images-11-_jpeg.rf.f2686fb7f9af8cd76f48a302af050e65.jpg: 416x416 9 Car-fire-HK8Es, 215.4ms
# image 2/4 /content/datasets/Car-fire-1/test/images/images-18-_jpeg.rf.d9d5932def1f8053eff4fc2a797896fa.jpg: 416x416 26 Car-fire-HK8Es, 208.9ms
# ...

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
